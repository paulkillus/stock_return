# %% [markdown]
# # Project: Predicting Stock Price & Return
# Deep Learning
# ## ver 0.1
# All guidance and guildlines provided by Romeo Kienzler

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#let the notebook display full length of the data columns
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv("data_feature_created.csv")

# %%
feature_names = ['loblaw_ma14', 'loblaw_rsi14', 'loblaw_ma30', 'loblaw_rsi30', 'loblaw_ma50', 'loblaw_rsi50', 'loblaw_ma200', 'loblaw_rsi200', 'loblaw_5d_pct', 'loblaw_price', 'loblaw_volume_1d_pct_SMA', 'metro_ma14', 'metro_rsi14', 'metro_ma30', 'metro_rsi30', 'metro_ma50', 'metro_rsi50', 'metro_ma200', 'metro_rsi200', 'metro_5d_pct', 'metro_price', 'metro_volume_1d_pct_SMA', 'gwl_ma14', 'gwl_rsi14', 'gwl_ma30', 'gwl_rsi30', 'gwl_ma50', 'gwl_rsi50', 'gwl_ma200', 'gwl_rsi200', 'gwl_5d_pct', 'gwl_price', 'gwl_volume_1d_pct_SMA', 'empa_ma14', 'empa_rsi14', 'empa_ma30', 'empa_rsi30', 'empa_ma50', 'empa_rsi50', 'empa_ma200', 'empa_rsi200', 'empa_5d_pct', 'empa_price', 'empa_volume_1d_pct_SMA', 'atd_ma14', 'atd_rsi14', 'atd_ma30', 'atd_rsi30', 'atd_ma50', 'atd_rsi50', 'atd_ma200', 'atd_rsi200', 'atd_5d_pct', 'atd_price', 'atd_volume_1d_pct_SMA', 'tsx_ma14', 'tsx_rsi14', 'tsx_ma30', 'tsx_rsi30', 'tsx_ma50', 'tsx_rsi50', 'tsx_ma200', 'tsx_rsi200', 'tsx_5d_pct', 'tsx_price', 'tsx_volume_1d_pct_SMA', 'sp500_ma14', 'sp500_rsi14', 'sp500_ma30', 'sp500_rsi30', 'sp500_ma50', 'sp500_rsi50', 'sp500_ma200', 'sp500_rsi200', 'sp500_5d_pct', 'sp500_price', 'sp500_volume_1d_pct_SMA', 'BCPI', 'CPI', 'bank_interest', 'CEER', 'trend_grocery_store', 'trend_loblaws', 'trend_stock']

# %%
features = df[feature_names]
targets = df[['loblaws_5d_return_level']].values.ravel() + 2

# %%
train_size = int(0.75 * features.shape[0])
train_features = features[:train_size]
train_targets = targets[:train_size]
test_features = features[train_size:]
test_targets = targets[train_size:]

print(train_features.shape, train_targets.shape)
print(test_features.shape, test_targets.shape)
# Out:
# (2920, 84) (2920,)
# (974, 84) (974,)

# %%
from sklearn.preprocessing import scale

# Standardize the train and test features
scaled_train_features = scale(train_features)
scaled_test_features = scale(test_features)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Create model with dropout
model = Sequential()
model.add(Dense(100, input_dim=scaled_train_features.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))

# Fit model with mean squared error loss function
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(scaled_train_features, train_targets, epochs=120)
plt.plot(history.history['loss'])
test_pred = model.predict(scaled_test_features)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(np.argmax(test_pred, axis=1), test_targets)
# Out:
# array([[28, 38, 45, 38, 36],
#        [15, 34, 35, 28, 19],
#        [35, 44, 55, 45, 23],
#        [22, 33, 52, 33, 34],
#        [27, 54, 73, 66, 62]])

# %%
pd.Series(test_pred.dot([-2,-1,0,1,2])).plot()

# %%
pd.Series(test_targets).plot()

# %%
from sklearn.metrics import r2_score

# Evaluate the R^2 scores
print(r2_score(train_targets, train_pred))
print(r2_score(test_targets, test_pred))
# Out:
# 0.006255009856767968
# -0.014458718543206794

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM

# %%
(train_features.shape[0] - 28) % 64
# Out:
# 12

# %%
from sklearn.preprocessing import scale

# Standardize the train and test features
scaled_features = scale(features)

# %%
scaled_features.shape
# Out:
# (3894, 84)

# %%
batch_size = 64
epochs = 120
timesteps = 5

# %%
scaled_lstm_features = []
for column in range(scaled_features.shape[1]):
    time_series = []
    for i in range(len(scaled_features) - timesteps):
        time_series.append(scaled_features[i:i + timesteps, column])
#    time_series = np.dstack(time_series)
    scaled_lstm_features.append(time_series)
scaled_lstm_features = np.dstack(scaled_lstm_features)
print(type(scaled_lstm_features))
print(scaled_lstm_features.shape)
# Out:
# <class 'numpy.ndarray'>
# (3889, 5, 84)

# %%
lstm_targets = pd.get_dummies(targets)

# %%
train_size = int(0.85 * scaled_lstm_features.shape[0])
train_start = train_size % batch_size

scaled_train_features = scaled_lstm_features[train_start:train_size]
train_targets = lstm_targets[train_start:train_size]
scaled_test_features = scaled_lstm_features[train_size:]
test_targets = lstm_targets[train_size:-5]

print(scaled_train_features.shape, train_targets.shape)
print(scaled_test_features.shape, test_targets.shape)
# Out:
# (3264, 5, 84) (3264, 5)
# (584, 5, 84) (584, 5)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(scaled_train_features.shape[1], scaled_train_features.shape[2]),dropout=0.7, recurrent_dropout=0.7))
model.add(Dense(5, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

history = model.fit(scaled_train_features, train_targets, epochs=epochs, batch_size=batch_size, 
                    validation_data=(scaled_test_features, test_targets), verbose=2, shuffle=False)

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Train on 3264 samples, validate on 584 samples
# Epoch 1/120
#  - 5s - loss: 1.6245 - val_loss: 1.6007
# Epoch 2/120
#  - 1s - loss: 1.5464 - val_loss: 1.5530
# Epoch 3/120
#  - 1s - loss: 1.5042 - val_loss: 1.5140
# Epoch 4/120
#  - 1s - loss: 1.4771 - val_loss: 1.4900
# Epoch 5/120
#  - 1s - loss: 1.4535 - val_loss: 1.4709
# Epoch 6/120
#  - 1s - loss: 1.4359 - val_loss: 1.4319
# Epoch 7/120
#  - 1s - loss: 1.4031 - val_loss: 1.4076
# Epoch 8/120
#  - 1s - loss: 1.3864 - val_loss: 1.3858
# Epoch 9/120
#  - 1s - loss: 1.3694 - val_loss: 1.3629
# Epoch 10/120
#  - 1s - loss: 1.3431 - val_loss: 1.3424
# Epoch 11/120
#  - 1s - loss: 1.3325 - val_loss: 1.3243
# Epoch 12/120
#  - 1s - loss: 1.3201 - val_loss: 1.3103
# Epoch 13/120
#  - 1s - loss: 1.3138 - val_loss: 1.3095
# Epoch 14/120
#  - 1s - loss: 1.2862 - val_loss: 1.3022
# Epoch 15/120
#  - 1s - loss: 1.2808 - val_loss: 1.2956
# Epoch 16/120
#  - 1s - loss: 1.2779 - val_loss: 1.2887
# Epoch 17/120
#  - 1s - loss: 1.2676 - val_loss: 1.2829
# Epoch 18/120
#  - 1s - loss: 1.2562 - val_loss: 1.2681
# Epoch 19/120
#  - 1s - loss: 1.2513 - val_loss: 1.2690
# Epoch 20/120
#  - 1s - loss: 1.2454 - val_loss: 1.2665
# Epoch 21/120
#  - 1s - loss: 1.2409 - val_loss: 1.2588
# Epoch 22/120
#  - 1s - loss: 1.2393 - val_loss: 1.2518
# Epoch 23/120
#  - 1s - loss: 1.2162 - val_loss: 1.2461
# Epoch 24/120
#  - 1s - loss: 1.2316 - val_loss: 1.2422
# Epoch 25/120
#  - 1s - loss: 1.2185 - val_loss: 1.2391
# Epoch 26/120
#  - 1s - loss: 1.2135 - val_loss: 1.2315
# Epoch 27/120
#  - 1s - loss: 1.2068 - val_loss: 1.2297
# Epoch 28/120
#  - 1s - loss: 1.2079 - val_loss: 1.2276
# Epoch 29/120
#  - 1s - loss: 1.2082 - val_loss: 1.2250
# Epoch 30/120
#  - 1s - loss: 1.2009 - val_loss: 1.2249
# Epoch 31/120
#  - 1s - loss: 1.2020 - val_loss: 1.2267
# Epoch 32/120
#  - 1s - loss: 1.1880 - val_loss: 1.2267
# Epoch 33/120
#  - 1s - loss: 1.1855 - val_loss: 1.2121
# Epoch 34/120
#  - 1s - loss: 1.1918 - val_loss: 1.2134
# Epoch 35/120
#  - 1s - loss: 1.1857 - val_loss: 1.2092
# Epoch 36/120
#  - 1s - loss: 1.1809 - val_loss: 1.2110
# Epoch 37/120
#  - 1s - loss: 1.1807 - val_loss: 1.2027
# Epoch 38/120
#  - 1s - loss: 1.1727 - val_loss: 1.1975
# Epoch 39/120
#  - 1s - loss: 1.1692 - val_loss: 1.1942
# Epoch 40/120
#  - 1s - loss: 1.1621 - val_loss: 1.1927
# Epoch 41/120
#  - 1s - loss: 1.1554 - val_loss: 1.1924
# Epoch 42/120
#  - 1s - loss: 1.1628 - val_loss: 1.1879
# Epoch 43/120
#  - 1s - loss: 1.1587 - val_loss: 1.1875
# Epoch 44/120
#  - 1s - loss: 1.1463 - val_loss: 1.1840
# Epoch 45/120
#  - 1s - loss: 1.1403 - val_loss: 1.1804
# Epoch 46/120
#  - 1s - loss: 1.1353 - val_loss: 1.1746
# Epoch 47/120
#  - 1s - loss: 1.1380 - val_loss: 1.1685
# Epoch 48/120
#  - 1s - loss: 1.1422 - val_loss: 1.1668
# Epoch 49/120
#  - 1s - loss: 1.1313 - val_loss: 1.1714
# Epoch 50/120
#  - 1s - loss: 1.1397 - val_loss: 1.1644
# Epoch 51/120
#  - 1s - loss: 1.1292 - val_loss: 1.1714
# Epoch 52/120
#  - 1s - loss: 1.1426 - val_loss: 1.1675
# Epoch 53/120
#  - 1s - loss: 1.1330 - val_loss: 1.1703
# Epoch 54/120
#  - 1s - loss: 1.1284 - val_loss: 1.1659
# Epoch 55/120
#  - 1s - loss: 1.1295 - val_loss: 1.1688
# Epoch 56/120
#  - 1s - loss: 1.1208 - val_loss: 1.1636
# Epoch 57/120
#  - 1s - loss: 1.1167 - val_loss: 1.1581
# Epoch 58/120
#  - 1s - loss: 1.1153 - val_loss: 1.1554
# Epoch 59/120
#  - 1s - loss: 1.1080 - val_loss: 1.1542
# Epoch 60/120
#  - 1s - loss: 1.1152 - val_loss: 1.1542
# Epoch 61/120
#  - 1s - loss: 1.1063 - val_loss: 1.1575
# Epoch 62/120
#  - 1s - loss: 1.1117 - val_loss: 1.1573
# Epoch 63/120
#  - 1s - loss: 1.1030 - val_loss: 1.1580
# Epoch 64/120
#  - 1s - loss: 1.1012 - val_loss: 1.1515
# Epoch 65/120
#  - 1s - loss: 1.1101 - val_loss: 1.1486
# Epoch 66/120
#  - 1s - loss: 1.0988 - val_loss: 1.1527
# Epoch 67/120
#  - 1s - loss: 1.0984 - val_loss: 1.1483
# Epoch 68/120
#  - 1s - loss: 1.0981 - val_loss: 1.1457
# Epoch 69/120
#  - 1s - loss: 1.0992 - val_loss: 1.1477
# Epoch 70/120
#  - 1s - loss: 1.1101 - val_loss: 1.1445
# Epoch 71/120
#  - 1s - loss: 1.0887 - val_loss: 1.1408
# Epoch 72/120
#  - 1s - loss: 1.0912 - val_loss: 1.1440
# Epoch 73/120
#  - 1s - loss: 1.0828 - val_loss: 1.1438
# Epoch 74/120
#  - 1s - loss: 1.0917 - val_loss: 1.1463
# Epoch 75/120
#  - 1s - loss: 1.0812 - val_loss: 1.1442
# Epoch 76/120
#  - 1s - loss: 1.0932 - val_loss: 1.1376
# Epoch 77/120
#  - 1s - loss: 1.0889 - val_loss: 1.1383
# Epoch 78/120
#  - 1s - loss: 1.0849 - val_loss: 1.1444
# Epoch 79/120
#  - 1s - loss: 1.0806 - val_loss: 1.1426
# Epoch 80/120
#  - 1s - loss: 1.0740 - val_loss: 1.1410
# Epoch 81/120
#  - 1s - loss: 1.0782 - val_loss: 1.1394
# Epoch 82/120
#  - 1s - loss: 1.0796 - val_loss: 1.1387
# Epoch 83/120
#  - 1s - loss: 1.0631 - val_loss: 1.1362
# Epoch 84/120
#  - 1s - loss: 1.0585 - val_loss: 1.1375
# Epoch 85/120
#  - 1s - loss: 1.0696 - val_loss: 1.1387
# Epoch 86/120
#  - 1s - loss: 1.0802 - val_loss: 1.1361
# Epoch 87/120
#  - 1s - loss: 1.0698 - val_loss: 1.1330
# Epoch 88/120
#  - 1s - loss: 1.0743 - val_loss: 1.1363
# Epoch 89/120
#  - 1s - loss: 1.0601 - val_loss: 1.1341
# Epoch 90/120
#  - 1s - loss: 1.0638 - val_loss: 1.1326
# Epoch 91/120
#  - 1s - loss: 1.0731 - val_loss: 1.1325
# Epoch 92/120
#  - 1s - loss: 1.0628 - val_loss: 1.1315
# Epoch 93/120
#  - 1s - loss: 1.0608 - val_loss: 1.1348
# Epoch 94/120
#  - 1s - loss: 1.0538 - val_loss: 1.1324
# Epoch 95/120
#  - 1s - loss: 1.0612 - val_loss: 1.1299
# Epoch 96/120
#  - 1s - loss: 1.0503 - val_loss: 1.1246
# Epoch 97/120
#  - 1s - loss: 1.0535 - val_loss: 1.1195
# Epoch 98/120
#  - 1s - loss: 1.0426 - val_loss: 1.1188
# Epoch 99/120
#  - 1s - loss: 1.0469 - val_loss: 1.1178
# Epoch 100/120
#  - 1s - loss: 1.0534 - val_loss: 1.1255
# Epoch 101/120
#  - 1s - loss: 1.0527 - val_loss: 1.1221
# Epoch 102/120
#  - 1s - loss: 1.0508 - val_loss: 1.1240
# Epoch 103/120
#  - 1s - loss: 1.0560 - val_loss: 1.1168
# Epoch 104/120
#  - 1s - loss: 1.0482 - val_loss: 1.1172
# Epoch 105/120
#  - 1s - loss: 1.0491 - val_loss: 1.1177
# Epoch 106/120
#  - 1s - loss: 1.0581 - val_loss: 1.1242
# Epoch 107/120
#  - 1s - loss: 1.0444 - val_loss: 1.1313
# Epoch 108/120
#  - 1s - loss: 1.0380 - val_loss: 1.1256
# Epoch 109/120
#  - 1s - loss: 1.0390 - val_loss: 1.1263
# Epoch 110/120
#  - 1s - loss: 1.0474 - val_loss: 1.1255
# Epoch 111/120
#  - 1s - loss: 1.0318 - val_loss: 1.1225
# Epoch 112/120
#  - 1s - loss: 1.0462 - val_loss: 1.1163
# Epoch 113/120
#  - 1s - loss: 1.0360 - val_loss: 1.1146
# Epoch 114/120
#  - 1s - loss: 1.0351 - val_loss: 1.1194
# Epoch 115/120
#  - 1s - loss: 1.0276 - val_loss: 1.1152
# Epoch 116/120
#  - 1s - loss: 1.0401 - val_loss: 1.1116
# Epoch 117/120
#  - 1s - loss: 1.0323 - val_loss: 1.1151
# Epoch 118/120
#  - 1s - loss: 1.0305 - val_loss: 1.1109
# Epoch 119/120
#  - 1s - loss: 1.0289 - val_loss: 1.1138
# Epoch 120/120
#  - 1s - loss: 1.0235 - val_loss: 1.1158

# %%
train_pred = model.predict(scaled_train_features)
test_pred = model.predict(scaled_test_features)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(np.argmax(test_pred, axis=1), np.argmax(test_targets.values, axis=1))
# Out:
# array([[53, 29, 20,  4,  1],
#        [ 8, 49, 26,  8,  0],
#        [ 8, 26, 67, 30,  3],
#        [ 1, 14, 41, 61, 29],
#        [ 0,  0, 10, 21, 75]])
