# %% [markdown]
# # Project: Predicting Stock Price & Return
# Deep Learning
# ## ver 0.1
# All guidance and guildlines provided by Romeo Kienzler

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#let the notebook display full length of the data columns
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv("data_feature_created.csv")

# %%
feature_names = ['loblaw_ma14', 'loblaw_rsi14', 'loblaw_ma30', 'loblaw_rsi30', 'loblaw_ma50', 'loblaw_rsi50', 'loblaw_ma200', 'loblaw_rsi200', 'loblaw_price', 'metro_ma14', 'metro_rsi14', 'metro_ma30', 'metro_rsi30', 'metro_ma50', 'metro_rsi50', 'metro_ma200', 'metro_rsi200', 'metro_price', 'gwl_ma14', 'gwl_rsi14', 'gwl_ma30', 'gwl_rsi30', 'gwl_ma50', 'gwl_rsi50', 'gwl_ma200', 'gwl_rsi200', 'gwl_price', 'empa_ma14', 'empa_rsi14', 'empa_ma30', 'empa_rsi30', 'empa_ma50', 'empa_rsi50', 'empa_ma200', 'empa_rsi200', 'empa_price', 'atd_ma14', 'atd_rsi14', 'atd_ma30', 'atd_rsi30', 'atd_ma50', 'atd_rsi50', 'atd_ma200', 'atd_rsi200', 'atd_price', 'tsx_ma14', 'tsx_rsi14', 'tsx_ma30', 'tsx_rsi30', 'tsx_ma50', 'tsx_rsi50', 'tsx_ma200', 'tsx_rsi200', 'tsx_price', 'sp500_ma14', 'sp500_rsi14', 'sp500_ma30', 'sp500_rsi30', 'sp500_ma50', 'sp500_rsi50', 'sp500_ma200', 'sp500_rsi200', 'sp500_price', 'BCPI', 'CPI', 'bank_interest', 'CEER', 'trend_grocery_store', 'trend_loblaws', 'trend_stock']

# %%
features = df[feature_names]
targets = df['loblaw_5d_future_pct']

# %%
train_size = int(0.85 * features.shape[0])
train_features = features[:train_size]
train_targets = targets[:train_size]
test_features = features[train_size:]
test_targets = targets[train_size:]

print(train_features.shape, train_targets.shape)
print(test_features.shape, test_targets.shape)
# Out:
# (3484, 70) (3484,)
# (615, 70) (615,)

# %%
from sklearn.preprocessing import scale

# Standardize the train and test features
scaled_train_features = scale(train_features)
scaled_test_features = scale(test_features)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
# Create model with dropout
model = Sequential()
model.add(Dense(100, input_dim=scaled_train_features.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))

# Fit model with mean squared error loss function
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', 'mape', 'cosine'])
history = model.fit(scaled_train_features, train_targets, epochs=25)
plt.plot(history.history['loss'])
plt.title('loss:' + str(round(history.history['loss'][-1], 6)))
plt.show()
# Out:
# Epoch 1/25
# 3484/3484 [==============================] - 4s 1ms/step - loss: 0.0878 - mean_squared_error: 0.0878 - mean_absolute_error: 0.1569 - mean_absolute_percentage_error: 1207377.7119 - cosine_proximity: -0.0195
# 3484/3484 [==============================] - 1s 156us/step - loss: 8.2675e-04 - mean_squared_error: 8.2675e-04 - mean_absolute_error: 0.0204 - mean_absolute_percentage_error: 20110.7051 - cosine_proximity: -0.0169
# Epoch 16/25
# 3484/3484 [==============================] - 1s 163us/step - loss: 8.7486e-04 - mean_squared_error: 8.7486e-04 - mean_absolute_error: 0.0205 - mean_absolute_percentage_error: 28927.8909 - cosine_proximity: -0.0250
# Epoch 17/25
# 3484/3484 [==============================] - 1s 180us/step - loss: 8.1609e-04 - mean_squared_error: 8.1609e-04 - mean_absolute_error: 0.0202 - mean_absolute_percentage_error: 12244.8780 - cosine_proximity: -0.0126
# Epoch 18/25
# 3484/3484 [==============================] - 1s 166us/step - loss: 8.1863e-04 - mean_squared_error: 8.1863e-04 - mean_absolute_error: 0.0202 - mean_absolute_percentage_error: 23640.4611 - cosine_proximity: -0.0149
# Epoch 19/25
# 3484/3484 [==============================] - 1s 177us/step - loss: 8.0539e-04 - mean_squared_error: 8.0539e-04 - mean_absolute_error: 0.0201 - mean_absolute_percentage_error: 8831.2613 - cosine_proximity: -0.0149
# Epoch 20/25
# 3484/3484 [==============================] - 1s 230us/step - loss: 8.1292e-04 - mean_squared_error: 8.1292e-04 - mean_absolute_error: 0.0201 - mean_absolute_percentage_error: 14951.9724 - cosine_proximity: -0.0023
# Epoch 21/25
# 3484/3484 [==============================] - 1s 237us/step - loss: 8.1215e-04 - mean_squared_error: 8.1215e-04 - mean_absolute_error: 0.0201 - mean_absolute_percentage_error: 16800.8250 - cosine_proximity: -0.0304
# Epoch 22/25
# 3484/3484 [==============================] - 1s 155us/step - loss: 8.1563e-04 - mean_squared_error: 8.1563e-04 - mean_absolute_error: 0.0202 - mean_absolute_percentage_error: 10422.8998 - cosine_proximity: -0.0103
# Epoch 23/25
# 3484/3484 [==============================] - 0s 143us/step - loss: 7.9404e-04 - mean_squared_error: 7.9404e-04 - mean_absolute_error: 0.0200 - mean_absolute_percentage_error: 10817.3914 - cosine_proximity: -0.0230
# Epoch 24/25
# 3484/3484 [==============================] - 1s 181us/step - loss: 8.0149e-04 - mean_squared_error: 8.0149e-04 - mean_absolute_error: 0.0200 - mean_absolute_percentage_error: 13709.6197 - cosine_proximity: -0.0224
# Epoch 25/25
# 3484/3484 [==============================] - 0s 136us/step - loss: 7.8688e-04 - mean_squared_error: 7.8688e-04 - mean_absolute_error: 0.0200 - mean_absolute_percentage_error: 9007.1902 - cosine_proximity: -0.0121

# %%
score = model.evaluate(scaled_test_features, test_targets, verbose=0)
print(score)
# Out:
# [0.00042105224040314194, 0.00042105224040314194, 0.014895598775124162, 119.01151711068502, -0.021138210606768848]

# %%
train_pred = model.predict(scaled_train_features)
test_pred = model.predict(scaled_test_features)

# %%
from sklearn.metrics import r2_score

# Evaluate the R^2 scores
print(r2_score(train_targets, train_pred))
print(r2_score(test_targets, test_pred))
# Out:
# 0.006255009856767968
# -0.014458718543206794

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM

# %%
(train_features.shape[0] - 28) % 64
# Out:
# 0

# %%
from sklearn.preprocessing import scale

# Standardize the train and test features
scaled_features = scale(features)

# %%
scaled_features.shape
# Out:
# (4099, 70)

# %%
batch_size = 64
epochs = 120
timesteps = 5

# %%
scaled_lstm_features = []
for column in range(scaled_features.shape[1]):
    time_series = []
    for i in range(len(scaled_features) - timesteps):
        time_series.append(scaled_features[i:i + timesteps, column])
#    time_series = np.dstack(time_series)
    scaled_lstm_features.append(time_series)
scaled_lstm_features = np.dstack(scaled_lstm_features)
print(type(scaled_lstm_features))
print(scaled_lstm_features.shape)
# Out:
# <class 'numpy.ndarray'>
# (4094, 5, 70)

# %%
train_size = int(0.85 * scaled_lstm_features.shape[0])
train_start = train_size % batch_size

scaled_train_features = scaled_lstm_features[train_start:train_size]
train_targets = targets[train_start:train_size]
scaled_test_features = scaled_lstm_features[train_size:]
test_targets = targets[train_size:-5]

print(scaled_train_features.shape, train_targets.shape)
print(scaled_test_features.shape, test_targets.shape)
# Out:
# (3456, 5, 70) (3456,)
# (615, 5, 70) (615,)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(scaled_train_features.shape[1], scaled_train_features.shape[2])))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

history = model.fit(scaled_train_features, train_targets, epochs=epochs, batch_size=batch_size, 
                    validation_data=(scaled_test_features, test_targets), verbose=2, shuffle=False)

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Train on 3456 samples, validate on 615 samples
# Epoch 1/120
#  - 5s - loss: 0.0484 - val_loss: 0.0988
# Epoch 2/120
#  - 1s - loss: 0.0393 - val_loss: 0.0696
# Epoch 3/120
#  - 1s - loss: 0.0474 - val_loss: 0.0365
# Epoch 4/120
#  - 1s - loss: 0.0379 - val_loss: 0.0584
# Epoch 5/120
#  - 1s - loss: 0.0151 - val_loss: 0.0572
# Epoch 6/120
#  - 1s - loss: 0.0111 - val_loss: 0.0368
# Epoch 7/120
#  - 1s - loss: 0.0122 - val_loss: 0.0415
# Epoch 8/120
#  - 1s - loss: 0.0085 - val_loss: 0.0174
# Epoch 9/120
#  - 1s - loss: 0.0083 - val_loss: 0.0154
# Epoch 10/120
#  - 1s - loss: 0.0074 - val_loss: 0.0149
# Epoch 11/120
#  - 1s - loss: 0.0032 - val_loss: 0.0244
# Epoch 12/120
#  - 1s - loss: 0.0026 - val_loss: 0.0247
# Epoch 13/120
#  - 1s - loss: 0.0027 - val_loss: 0.0180
# Epoch 14/120
#  - 1s - loss: 0.0029 - val_loss: 0.0198
# Epoch 15/120
#  - 1s - loss: 0.0022 - val_loss: 0.0219
# Epoch 16/120
#  - 1s - loss: 0.0019 - val_loss: 0.0209
# Epoch 17/120
#  - 1s - loss: 0.0024 - val_loss: 0.0235
# Epoch 18/120
#  - 1s - loss: 0.0027 - val_loss: 0.0142
# Epoch 19/120
#  - 1s - loss: 0.0034 - val_loss: 0.0137
# Epoch 20/120
#  - 1s - loss: 0.0027 - val_loss: 0.0227
# Epoch 21/120
#  - 1s - loss: 0.0027 - val_loss: 0.0243
# Epoch 22/120
#  - 1s - loss: 0.0040 - val_loss: 0.0191
# Epoch 23/120
#  - 1s - loss: 0.0035 - val_loss: 0.0161
# Epoch 24/120
#  - 1s - loss: 0.0070 - val_loss: 0.0305
# Epoch 25/120
#  - 1s - loss: 0.0044 - val_loss: 0.0289
# Epoch 26/120
#  - 1s - loss: 0.0112 - val_loss: 0.0223
# Epoch 27/120
#  - 1s - loss: 0.0071 - val_loss: 0.0271
# Epoch 28/120
#  - 1s - loss: 0.0066 - val_loss: 0.0123
# Epoch 29/120
#  - 1s - loss: 0.0044 - val_loss: 0.0145
# Epoch 30/120
#  - 1s - loss: 0.0023 - val_loss: 0.0218
# Epoch 31/120
#  - 1s - loss: 0.0015 - val_loss: 0.0109
# Epoch 32/120
#  - 1s - loss: 0.0017 - val_loss: 0.0172
# Epoch 33/120
#  - 1s - loss: 0.0012 - val_loss: 0.0106
# Epoch 34/120
#  - 1s - loss: 6.7040e-04 - val_loss: 0.0132
# Epoch 35/120
#  - 1s - loss: 5.9272e-04 - val_loss: 0.0119
# Epoch 36/120
#  - 1s - loss: 5.2837e-04 - val_loss: 0.0103
# Epoch 37/120
#  - 1s - loss: 4.6015e-04 - val_loss: 0.0127
# Epoch 38/120
#  - 1s - loss: 4.3633e-04 - val_loss: 0.0120
# Epoch 39/120
#  - 1s - loss: 5.0072e-04 - val_loss: 0.0120
# Epoch 40/120
#  - 1s - loss: 4.8696e-04 - val_loss: 0.0133
# Epoch 41/120
#  - 1s - loss: 4.1265e-04 - val_loss: 0.0117
# Epoch 42/120
#  - 1s - loss: 4.0324e-04 - val_loss: 0.0116
# Epoch 43/120
#  - 1s - loss: 4.2811e-04 - val_loss: 0.0126
# Epoch 44/120
#  - 1s - loss: 4.4480e-04 - val_loss: 0.0109
# Epoch 45/120
#  - 1s - loss: 3.9564e-04 - val_loss: 0.0112
# Epoch 46/120
#  - 1s - loss: 4.0204e-04 - val_loss: 0.0120
# Epoch 47/120
#  - 1s - loss: 3.9106e-04 - val_loss: 0.0108
# Epoch 48/120
#  - 1s - loss: 3.8149e-04 - val_loss: 0.0108
# Epoch 49/120
#  - 1s - loss: 4.1617e-04 - val_loss: 0.0116
# Epoch 50/120
#  - 1s - loss: 4.9201e-04 - val_loss: 0.0099
# Epoch 51/120
#  - 1s - loss: 4.8967e-04 - val_loss: 0.0082
# Epoch 52/120
#  - 1s - loss: 4.5584e-04 - val_loss: 0.0085
# Epoch 53/120
#  - 1s - loss: 5.4967e-04 - val_loss: 0.0101
# Epoch 54/120
#  - 1s - loss: 6.3734e-04 - val_loss: 0.0101
# Epoch 55/120
#  - 1s - loss: 0.0016 - val_loss: 0.0095
# Epoch 56/120
#  - 1s - loss: 0.0042 - val_loss: 0.0178
# Epoch 57/120
#  - 1s - loss: 0.0029 - val_loss: 0.0318
# Epoch 58/120
#  - 1s - loss: 0.0035 - val_loss: 0.0102
# Epoch 59/120
#  - 1s - loss: 0.0033 - val_loss: 0.0213
# Epoch 60/120
#  - 1s - loss: 0.0027 - val_loss: 0.0245
# Epoch 61/120
#  - 1s - loss: 0.0033 - val_loss: 0.0151
# Epoch 62/120
#  - 1s - loss: 0.0026 - val_loss: 0.0082
# Epoch 63/120
#  - 1s - loss: 0.0025 - val_loss: 0.0115
# Epoch 64/120
#  - 1s - loss: 0.0037 - val_loss: 0.0085
# Epoch 65/120
#  - 1s - loss: 0.0025 - val_loss: 0.0097
# Epoch 66/120
#  - 1s - loss: 0.0016 - val_loss: 0.0087
# Epoch 67/120
#  - 1s - loss: 0.0016 - val_loss: 0.0050
# Epoch 68/120
#  - 1s - loss: 8.6853e-04 - val_loss: 0.0055
# Epoch 69/120
#  - 1s - loss: 0.0010 - val_loss: 0.0064
# Epoch 70/120
#  - 1s - loss: 5.2889e-04 - val_loss: 0.0062
# Epoch 71/120
#  - 1s - loss: 6.0979e-04 - val_loss: 0.0053
# Epoch 72/120
#  - 1s - loss: 4.5927e-04 - val_loss: 0.0052
# Epoch 73/120
#  - 1s - loss: 3.4354e-04 - val_loss: 0.0052
# Epoch 74/120
#  - 1s - loss: 3.0917e-04 - val_loss: 0.0056
# Epoch 75/120
#  - 1s - loss: 2.9907e-04 - val_loss: 0.0053
# Epoch 76/120
#  - 1s - loss: 3.0070e-04 - val_loss: 0.0053
# Epoch 77/120
#  - 1s - loss: 3.0739e-04 - val_loss: 0.0054
# Epoch 78/120
#  - 1s - loss: 3.0988e-04 - val_loss: 0.0056
# Epoch 79/120
#  - 1s - loss: 2.9523e-04 - val_loss: 0.0056
# Epoch 80/120
#  - 1s - loss: 2.8725e-04 - val_loss: 0.0054
# Epoch 81/120
#  - 1s - loss: 2.8703e-04 - val_loss: 0.0052
# Epoch 82/120
#  - 1s - loss: 2.8686e-04 - val_loss: 0.0051
# Epoch 83/120
#  - 1s - loss: 2.8685e-04 - val_loss: 0.0053
# Epoch 84/120
#  - 1s - loss: 2.8358e-04 - val_loss: 0.0054
# Epoch 85/120
#  - 1s - loss: 2.9013e-04 - val_loss: 0.0054
# Epoch 86/120
#  - 1s - loss: 2.9866e-04 - val_loss: 0.0053
# Epoch 87/120
#  - 1s - loss: 2.9434e-04 - val_loss: 0.0051
# Epoch 88/120
#  - 1s - loss: 3.0769e-04 - val_loss: 0.0054
# Epoch 89/120
#  - 1s - loss: 3.4578e-04 - val_loss: 0.0063
# Epoch 90/120
#  - 1s - loss: 3.5284e-04 - val_loss: 0.0069
# Epoch 91/120
#  - 2s - loss: 4.9923e-04 - val_loss: 0.0070
# Epoch 92/120
#  - 1s - loss: 6.4440e-04 - val_loss: 0.0060
# Epoch 93/120
#  - 1s - loss: 6.1463e-04 - val_loss: 0.0042
# Epoch 94/120
#  - 1s - loss: 0.0012 - val_loss: 0.0056
# Epoch 95/120
#  - 2s - loss: 0.0021 - val_loss: 0.0119
# Epoch 96/120
#  - 2s - loss: 0.0017 - val_loss: 0.0093
# Epoch 97/120
#  - 1s - loss: 0.0024 - val_loss: 0.0103
# Epoch 98/120
#  - 1s - loss: 0.0027 - val_loss: 0.0039
# Epoch 99/120
#  - 2s - loss: 0.0015 - val_loss: 0.0047
# Epoch 100/120
#  - 2s - loss: 0.0011 - val_loss: 0.0049
# Epoch 101/120
#  - 2s - loss: 5.4387e-04 - val_loss: 0.0037
# Epoch 102/120
#  - 1s - loss: 3.7341e-04 - val_loss: 0.0046
# Epoch 103/120
#  - 1s - loss: 3.2424e-04 - val_loss: 0.0042
# Epoch 104/120
#  - 1s - loss: 2.9923e-04 - val_loss: 0.0040
# Epoch 105/120
#  - 1s - loss: 2.9206e-04 - val_loss: 0.0038
# Epoch 106/120
#  - 1s - loss: 2.9725e-04 - val_loss: 0.0039
# Epoch 107/120
#  - 1s - loss: 2.8435e-04 - val_loss: 0.0041
# Epoch 108/120
#  - 1s - loss: 2.7221e-04 - val_loss: 0.0041
# Epoch 109/120
#  - 1s - loss: 2.6655e-04 - val_loss: 0.0044
# Epoch 110/120
#  - 1s - loss: 2.6371e-04 - val_loss: 0.0046
# Epoch 111/120
#  - 1s - loss: 2.6002e-04 - val_loss: 0.0047
# Epoch 112/120
#  - 1s - loss: 2.5740e-04 - val_loss: 0.0046
# Epoch 113/120
#  - 2s - loss: 2.5289e-04 - val_loss: 0.0046
# Epoch 114/120
#  - 2s - loss: 2.4893e-04 - val_loss: 0.0045
# Epoch 115/120
#  - 2s - loss: 2.4519e-04 - val_loss: 0.0044
# Epoch 116/120
#  - 1s - loss: 2.4262e-04 - val_loss: 0.0044
# Epoch 117/120
#  - 2s - loss: 2.4132e-04 - val_loss: 0.0045
# Epoch 118/120
#  - 2s - loss: 2.3993e-04 - val_loss: 0.0046
# Epoch 119/120
#  - 1s - loss: 2.3771e-04 - val_loss: 0.0045
# Epoch 120/120
#  - 1s - loss: 2.3704e-04 - val_loss: 0.0046

# %%
train_pred = model.predict(scaled_train_features)
test_pred = model.predict(scaled_test_features)

# %%
from sklearn.metrics import r2_score

# Evaluate the R^2 scores
print(r2_score(train_targets, train_pred))
print(r2_score(test_targets, test_pred))
# Out:
# 0.6930162619578094
# -10.148181254124863

# %%
test_targets.values
# Out:
# array([-0.00209874,  0.00368121,  0.01315855,  0.01817798,  0.01584831,
#         0.0098538 ,  0.00681122, -0.00207768, -0.0166889 , -0.01794165,
#        -0.01482254, -0.01599701, -0.0139165 , -0.03892839, -0.03573805,
#        -0.03816577, -0.03356719, -0.03324881,  0.00316152,  0.00702771,
#         0.01019658,  0.0034322 , -0.01096304, -0.01205292, -0.01689747,
#        -0.02386812, -0.02243872, -0.01371486, -0.01718797, -0.01134123,
# %%
df['loblaw_5d_future_pct'][train_size:-5].plot()

# %%
model = Sequential()
#model.add(Embedding(train_features.shape[0], 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mse', optimizer='adam', metrics=['mse'])
model.fit(train_features.values, train_targets.values, batch_size=32, epochs=25, validation_data=\
        (test_features.values, test_targets.values))
model.evaluate(test_features.values,test_targets,batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d9cbe037e47d> in <module>()
#       5
#       6 model.compile(loss='mse', optimizer='adam', metrics=['mse'])
# ----> 7 model.fit(train_features.values, train_targets.values, batch_size=32, epochs=25, validation_data=        (test_features.values, test_targets.values))
#       8 model.evaluate(test_features.values,test_targets,batch_size=32)
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     675             # to match the value shapes.
#     676             if not self.inputs:
# --> 677                 self._set_inputs(x)
#     678
#     679         if y is not None:
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in _set_inputs(self, inputs, outputs, training)
#     587                 assert len(inputs) == 1
#     588                 inputs = inputs[0]
# --> 589             self.build(input_shape=(None,) + inputs.shape[1:])
#     590             return
#     591
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/engine/sequential.py in build(self, input_shape)
#     219             self.inputs = [x]
#     220             for layer in self._layers:
# --> 221                 x = layer(x)
#     222             self.outputs = [x]
#     223             self._build_input_shape = input_shape
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     530
#     531         if initial_state is None and constants is None:
# --> 532             return super(RNN, self).__call__(inputs, **kwargs)
#     533
#     534         # If any of `initial_state` or `constants` are specified and are Keras
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     412                 # Raise exceptions in case the input is not compatible
#     413                 # with the input_spec specified in the layer constructor.
# --> 414                 self.assert_input_compatibility(inputs)
#     415
#     416                 # Collect input shapes to build layer.
#
# /home/paul/anaconda3/lib/python3.7/site-packages/keras/engine/base_layer.py in assert_input_compatibility(self, inputs)
#     309                                      self.name + ': expected ndim=' +
#     310                                      str(spec.ndim) + ', found ndim=' +
# --> 311                                      str(K.ndim(x)))
#     312             if spec.max_ndim is not None:
#     313                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer lstm_5: expected ndim=3, found ndim=2
