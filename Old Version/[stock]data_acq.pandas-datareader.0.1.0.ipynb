# %% [markdown]
# # Use pandas-datareader Package to Get Financial Information
#
# For this project, we use free APIs to get stock information. Some other commercial APIs are available on the internet, such as: https://intrinio.com/

# %%
#install the package
# !pip install pandas_datareader

# %%
#import packages
import pandas as pd
import pandas_datareader as pdr

from pandas_datareader import data, wb

# %% [markdown]
# ## 1. Get the list of stocks in Toronto Stock Exchange
# The listings of TSX/TSXV has been downloaded from the following link:
# https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=11&ved=2ahUKEwjC8Kf7jY3lAhVQh-AKHY1mBGYQFjAKegQIARAC&url=https%3A%2F%2Fwww.tsx.com%2Fresource%2Fen%2F571&usg=AOvVaw0t7ZrObTwMOVfTAbPG9YRQ

# %%
listings = pd.read_csv("tsx-andamp-tsxv-listed-companies-2019-09-13-en.csv", 
                       parse_dates=['Date of \nTSX Listing\nYYYYMMDD'])

# %%
listings.head()
# Out:
#      Co_ID Exchange                                               Name  \
# 0  FIV0003      TSX                                       5N Plus Inc.
# 1  AAW0001      TSX                  A&W Revenue Royalties Income Fund
# 2  FIR0005      TSX  Aberdeen Asia-Pacific Income Investment Compan...
# 3  ABE0005      TSX                        Aberdeen International Inc.
# 4  ABS0003      TSX                      Absolute Software Corporation
#
#   Root\nTicker  QMV(C$)\n31-August-2019   O/S Shares\n31-August-2019   \
# 0          VNP              195,022,756                   83,343,058
# 1           AW              571,728,957                   14,064,673
# 2          FAP              177,851,156                   50,814,616
# 3          AAB                4,802,614                   96,052,282
# 4          ABT              328,576,276                   41,697,497
#
#                            Sector Sub\nSector Listing Type  \
# 0               Clean Technology          NaN          IPO
# 1   Consumer Products & Services          NaN          NaN
# 2               Closed-End Funds          NaN          NaN
# 3             Financial Services          NaN    TSXV Grad
# 4                     Technology          NaN    TSXV Grad
#
#   Date of \nTSX Listing\nYYYYMMDD  ... Zinc Rare Earths Potash Lithium  \
# 0                      2007-12-19  ...  NaN         NaN    NaN     NaN
# 1                      2002-02-14  ...  NaN         NaN    NaN     NaN
# 2                      1986-06-11  ...  NaN         NaN    NaN     NaN
# 3                      2008-01-30  ...  NaN         NaN    NaN     NaN
# 4                      2005-12-02  ...  NaN         NaN    NaN     NaN
#
#   Uranium  Coal  Tungsten  Base & Precious Metals  \
# 0     NaN   NaN       NaN                     NaN
# 1     NaN   NaN       NaN                     NaN
# 2     NaN   NaN       NaN                     NaN
# 3     NaN   NaN       NaN                     NaN
# 4     NaN   NaN       NaN                     NaN
#
#   Mineral Properties (General) Other Properties
# 0                          NaN              NaN
# 1                          NaN              NaN
# 2                          NaN              NaN
# 3                          NaN              NaN
# 4                          NaN              NaN
#
# [5 rows x 66 columns]

# %%
listings.columns
# Out:
# Index(['Co_ID', 'Exchange', 'Name', 'Root\nTicker',
#        ' QMV(C$)\n31-August-2019 ', ' O/S Shares\n31-August-2019 ', 'Sector',
#        'Sub\nSector', 'Listing Type', 'Date of \nTSX Listing\nYYYYMMDD',
#        'HQ\nLocation', 'HQ\nRegion', 'Interlisted\nCode_I',
#        'Interlisted\nCode_II', 'Listed on OTC', 'TSX \nVenture \nGrad',
#        'Former\nCPC', 'Index', 'Clean Technology Primary Industry',
#        'Clean Technology Sub-Sector', 'Technology Sub-Sector ',
#        'Consumer Products & Services\nSub-Sector', 'Real Estate Sub-Sector ',
#        'Life Sciences Sub-Sector', 'USA_City', 'USA_State', 'Asia Region',
#        'Israel Related', 'Place of Incorporation\nC=Canada\nU=USA\nF=Foreign',
#        'Fund Family', 'SP Grouping', 'SP_Type', 'SP_Sub',
#        'Income Trust \nConversion', ' Volume YTD\n31-August-2019 ',
#        ' Value (C$) YTD\n31-August-2019 ',
#        ' Number of \nTrades YTD\n31-August-2019 ',
#        ' Number of\nMonths of \nTrading Data ', 'AFRICA', 'AUS/NZ/PNG',
#        'CANADA', 'CHINA & ASIA', 'LATIN AMERICA', 'OTHER', 'UK/EUROPE', 'USA',
#        'Oil and Gas', 'Gold', 'Silver', 'Copper', 'Nickel', 'Diamond',
#        'Molybdenum', 'Platinum/PGM', 'Iron', 'Lead', 'Zinc', 'Rare Earths',
#        'Potash', 'Lithium', 'Uranium', 'Coal', 'Tungsten',
#        'Base & Precious Metals', 'Mineral Properties (General)',
#        'Other Properties'],
#       dtype='object')

# %% [markdown]
#
#
# The Ticker of National Bank of Canada is "NA", and it was read as NaN by pandas read_csv methods. Here we fixed it manually.

# %%
listings[listings['Root\nTicker'].apply(lambda x: type(x)) == float]
# Out:
#         Co_ID Exchange                     Name Root\nTicker  \
# 1086  NAT0002      TSX  National Bank of Canada          NaN
#
#       QMV(C$)\n31-August-2019   O/S Shares\n31-August-2019   \
# 1086           22,993,740,736                  433,577,427
#
#                     Sector Sub\nSector Listing Type  \
# 1086   Financial Services          NaN          NaN
#
#      Date of \nTSX Listing\nYYYYMMDD  ... Zinc Rare Earths Potash Lithium  \
# 1086                      1979-11-01  ...  NaN         NaN    NaN     NaN
#
#      Uranium  Coal  Tungsten  Base & Precious Metals  \
# 1086     NaN   NaN       NaN                     NaN
#
#      Mineral Properties (General) Other Properties
# 1086                          NaN              NaN
#
# [1 rows x 66 columns]

# %%
listings.loc[listings.Co_ID == 'NAT0002', 'Root\nTicker'] = 'NA'

# %% [markdown]
# Only keep a few key columns and rename them. Change data types accordingly.

# %%
keep_cols = ['Exchange', 'Name', 'Root\nTicker',
       ' QMV(C$)\n31-August-2019 ', 'Sector','Date of \nTSX Listing\nYYYYMMDD']
listings = listings[keep_cols]
listings.columns = ['exchange', 'name', 'ticker',
       'market_value', 'sector','date_of_listing']

# %%
listings['exchange']= listings['exchange'].apply(lambda x: x.strip())
listings['name']= listings['name'].apply(lambda x: x.strip())
listings['ticker']= listings['ticker'].apply(lambda x: x.strip())
listings['sector']= listings['sector'].apply(lambda x: x.strip())
listings['market_value']= listings['market_value'].apply(
    lambda x: x.strip()).apply(lambda x: x.replace(',',''))
                                             
listings['market_value'] = pd.to_numeric(listings['market_value'])

listings.set_index('ticker', inplace = True)

# %% [markdown]
# Remove the ETPs (Exchange-Traded Products) cause they have different data structures as the regular company's stocks.

# %%
listings.sector.value_counts()
# Out:
# ETP                               680
# Mining                            213
# Industrial Products & Services    123
# Closed-End Funds                   92
# Financial Services                 73
# Consumer Products & Services       70
# Oil & Gas                          70
# Real Estate                        61
# Life Sciences                      56
# Technology                         51
# Clean Technology                   31
# Comm & Media                       23
# Utilities & Pipelines              21
# SPAC                                2
# Name: sector, dtype: int64

# %% [markdown]
# Keep only the stocks listed before 2004. Save to csv file for future use.

# %%
listings[(listings.sector != 'ETP') & (listings.date_of_listing < '2004')].to_csv('TSX_listing_2004.csv')

# %% [markdown]
# ## 2. Get the stock prices

# %%
listings = listings[(listings.sector != 'ETP') & (listings.date_of_listing < '2004')]

# %%
listings.index[1]
# Out:
# 'FAP'

# %%
from datetime import date
import requests
from time import sleep

# %%
def get_stock(symbol):
    '''
    Get stock daily adjuested close price and volume using alphavantage API
    '''
    apikey = "39ID5KS0RJQLNZGL"
    base_url = "https://www.alphavantage.co/query?"
    function = "TIME_SERIES_DAILY_ADJUSTED"
    outputsize = "full"
    
    #construct the api url
    url = base_url + "function={}&symbol={}&outputsize={}&apikey={}".format(
    function, symbol, outputsize, apikey)

    r = requests.get(url)
    
    #parse the result, change the datatypes 
    try:
        df = pd.DataFrame(r.json()['Time Series (Daily)']).transpose(
            )[['5. adjusted close','6. volume']].reset_index()
    except:
        return None
    df.columns = ['date','price','volume']
    df['date'] = pd.to_datetime(df['date'])
    df['price'] = pd.to_numeric(df['price'])
    df['volume'] = pd.to_numeric(df['volume'])
    df = df.set_index('date')
    
    return df

# %%
df_price = get_stock(listings.index[1]+".TO")[['price']]
df_volume = get_stock(listings.index[1]+".TO")[['volume']]

# %%
df_price.head()
# Out:
#             price
# date
# 2019-10-08   3.35
# 2019-10-07   3.39
# 2019-10-04   3.38
# 2019-10-03   3.35
# 2019-10-02   3.38

# %%
df_volume.head()
# Out:
#             volume
# date
# 2019-10-08   33950
# 2019-10-07   56200
# 2019-10-04   30900
# 2019-10-03   56200
# 2019-10-02   44000

# %%
#This cell scrap the entire list, so it will take very long to finish
'''
for i, _ in listings.iterrows():
    df = get_stock(i+".TO")
    sleep(10)
    if df is not None:
        df_price = df_price.join(df['price'],rsuffix = i)
        df_volume = df_volume.join(df['volume'],rsuffix = i)
        print("get info of {}".format(i))
    else:
        print("failed to get {}".format(i))
'''
# Out:
# failed to get AW
# get info of FAP
# failed to get ACD
# failed to get DRX
# get info of AAV
# get info of ARE
# failed to get AEZS
# failed to get AGF
# get info of AJX
# get info of AEM
# get info of BOS
# failed to get AKT
# get info of ASR
# failed to get ALC
# get info of AQN
# failed to get ATD
# failed to get AP
# failed to get AMM
# get info of ALA
# failed to get ADW
# get info of APS
# get info of ARX
# failed to get ACO
# get info of ATA
# failed to get AVP
# get info of BAD
# get info of BLDP
# get info of BMO
# get info of BNS
# get info of ABX
# get info of BHC
# get info of BTE
# get info of BCE
# failed to get BEK
# failed to get BXE
# failed to get BLU
# get info of BR
# get info of BB
# failed to get RBN
# get info of GBT
# failed to get BEI
# failed to get BBD
# get info of BNP
# get info of BNE
# get info of BLX
# failed to get BPF
# failed to get BYD
# failed to get BBL
# get info of BRE
# failed to get BAM
# failed to get BPO
# failed to get BEP
# failed to get BUI
# get info of CAE
# failed to get CWL
# failed to get CAL
# get info of CFW
# get info of CGY
# get info of CCO
# failed to get CAR
# get info of CGI
# get info of CM
# get info of CNR
# get info of CNQ
# get info of CP
# failed to get CTC
# get info of CU
# get info of CWB
# get info of CCM
# get info of CFP
# failed to get ICE
# failed to get EIT
# failed to get CUP
# get info of CAS
# get info of CET
# failed to get CCL
# get info of CLS
# failed to get GIB
# failed to get CSH
# failed to get CHE
# get info of CIX
# get info of CGX
# failed to get CVG
# get info of CKI
# get info of CLR
# get info of CCA
# get info of CGO
# get info of CIGI
# failed to get CUF
# failed to get CMG
# failed to get CCS
# failed to get CSW
# get info of CORV
# failed to get CJR
# get info of BCB
# get info of CPG
# get info of CR
# get info of DSG
# failed to get DII
# failed to get D
# failed to get DC
# get info of DPM
# get info of ER
# failed to get EVT
# failed to get ELF
# get info of ELD
# get info of EFL
# get info of EMA
# failed to get EMP
# get info of ENB
# get info of ECA
# failed to get EDV
# get info of ERF
# get info of ENGH
# get info of ESI
# failed to get ETX
# get info of XTC
# get info of EXF
# get info of EXE
# get info of FFH
# failed to get FRX
# get info of FSZ
# get info of FTN
# get info of FTT
# failed to get FTG
# get info of FC
# get info of FCR
# get info of FM
# get info of FTS
# failed to get FT
# get info of FVL
# get info of FRU
# failed to get GDC
# get info of WN
# get info of GIL
# failed to get GVC
# failed to get GMX
# get info of GMP
# failed to get GSY
# get info of GSC
# failed to get GDL
# get info of GRT
# failed to get GWO
# failed to get GCG
# failed to get HR
# failed to get HMM
# failed to get HPS
# failed to get HBP
# get info of HRX
# failed to get HLF
# get info of HCG
# get info of HSE
# get info of HYG
# get info of IAG
# get info of IMG
# get info of IGM
# get info of III
# get info of IMO
# failed to get INC
# get info of IDG
# failed to get INQ
# failed to get IPCI
# get info of IPL
# get info of IFP
# get info of ITP
# get info of ITC
# get info of JOSE
# get info of JE
# failed to get KEG
# get info of KEY
# failed to get KMP
# get info of K
# failed to get KL
# get info of LIF
# failed to get LAS
# get info of LB
# get info of LNF
# get info of LNR
# get info of L
# failed to get LGT
# failed to get MKZ
# failed to get MPC
# get info of MAL
# get info of MG
# failed to get MEQ
# get info of MDI
# get info of MFC
# get info of MFI
# get info of MRE
# get info of MAXR
# get info of MKP
# failed to get MCB
# get info of MDF
# failed to get MRD
# get info of MX
# get info of MRU
# get info of MBX
# failed to get MID
# failed to get TPX
# get info of ME
# get info of MRC
# failed to get MRT
# get info of MPVD
# get info of MTL
# get info of NA
# get info of NGD
# failed to get BCI
# failed to get NIF
# get info of OSB
# failed to get PDL
# failed to get NWC
# get info of NPI
# get info of NZC
# get info of NG
# get info of NVA
# get info of NRI
# get info of OBE
# get info of ONC
# get info of ONEX
# get info of OTEX
# get info of ORV
# get info of PAAS
# get info of PKI
# failed to get PVS
# get info of PSI
# get info of PPL
# get info of PGF
# get info of PMT
# get info of PEY
# failed to get PFB
# get info of PHX
# failed to get PNP
# get info of POW
# get info of PWF
# get info of PD
# get info of PBH
# failed to get PIC
# failed to get PLI
# get info of PSD
# get info of QTRH
# failed to get QBR
# get info of QEC
# failed to get RAV
# failed to get RET
# get info of RCH
# failed to get REI
# failed to get RCI
# get info of RSI
# get info of RY
# failed to get RMX
# get info of RUS
# get info of SAP
# failed to get SIS
# get info of SMF
# failed to get SEC
# failed to get SJR
# get info of SCL
# get info of S
# get info of SW
# failed to get SRU
# get info of SNC
# failed to get SLR
# get info of EDT
# get info of CEF
# get info of STN
# failed to get SJ
# failed to get SCB
# failed to get SQP
# failed to get SOX
# get info of SLF
# get info of SU
# get info of SOY
# failed to get SWH
# get info of SPB
# get info of SWP
# failed to get SXI
# failed to get TBL
# get info of TNX
# get info of TRP
# failed to get TECK
# failed to get TCS
# get info of T
# get info of TFII
# get info of TH
# get info of TRI
# get info of X
# failed to get TCT
# failed to get TXT
# get info of TIH
# get info of TD
# failed to get TS
# get info of TOT
# get info of TXP
# get info of TA
# failed to get TRZ
# get info of TNP
# failed to get TCL
# get info of TGL
# get info of TSL
# get info of TCW
# get info of TOS
# get info of TRQ
# failed to get TVA
# failed to get TWC
# get info of UEX
# get info of UNS
# get info of UNC
# get info of VNR
# failed to get VLN
# get info of VET
# get info of VFF
# get info of VGZ
# get info of WJX
# failed to get WFC
# get info of WM
# get info of WBR
# get info of WDO
# get info of WFT
# failed to get W
# get info of WJA
# get info of WPRT
# get info of WTE
# failed to get WCM
# get info of WPK
# get info of YRI
# get info of Y
# get info of YRB
# get info of ZAR

# %%
df_price.head()
# Out:
#             price  priceFAP  priceAAV  priceARE  priceAJX  priceAEM  priceBOS  \
# date
# 2019-10-08   3.35      3.35      1.89     17.69      0.56     73.25      7.50
# 2019-10-07   3.39      3.39      1.90     17.62      0.53     72.02      7.70
# 2019-10-04   3.38      3.38      1.99     17.71      0.52     72.34      7.68
# 2019-10-03   3.35      3.35      2.03     17.61      0.51     71.28      7.60
# 2019-10-02   3.38      3.38      2.03     17.69      0.49     71.21      7.74
#
#             priceASR  priceAQN  priceALA  ...  priceWDO  priceWFT  priceWJA  \
# date                                      ...
# 2019-10-08      5.90       NaN     19.00  ...      6.58     49.37     30.62
# 2019-10-07      5.64     18.75     19.18  ...      6.25     50.00     30.63
# 2019-10-04      5.67     18.55     18.95  ...      6.35     51.62     30.61
# 2019-10-03      5.54     18.32     18.93  ...      6.21     51.42     30.60
# 2019-10-02      5.51     18.01     19.22  ...      6.22     51.01     30.64
#
#             priceWPRT  priceWTE  priceWPK  priceYRI  priceY  priceYRB  \
# date
# 2019-10-08       3.27     20.22     45.64      4.66    8.90      0.03
# 2019-10-07       3.37     20.36     45.83      4.51    8.28      0.03
# 2019-10-04       3.40     19.03     45.54      4.60    8.43      0.03
# 2019-10-03       3.29     19.30     45.98      4.50    8.32      0.03
# 2019-10-02       3.30     19.29     46.69      4.45    8.22      0.03
#
#             priceZAR
# date
# 2019-10-08      0.32
# 2019-10-07      0.33
# 2019-10-04      0.36
# 2019-10-03      0.36
# 2019-10-02      0.36
#
# [5 rows x 207 columns]

# %%
df_volume.head()
# Out:
#             volume  volumeFAP  volumeAAV  volumeARE  volumeAJX  volumeAEM  \
# date
# 2019-10-08   33950      33950   739872.0     531393      21009     587473
# 2019-10-07   56200      56200   524600.0     214000      21500     478800
# 2019-10-04   30900      30900   815900.0     130600       9000     561800
# 2019-10-03   56200      56200   829500.0     296000       1000     773200
# 2019-10-02   44000      44000   505200.0     177700      13100     759800
#
#             volumeBOS  volumeASR  volumeAQN  volumeALA  ...  volumeWDO  \
# date                                                    ...
# 2019-10-08      14915   816397.0        NaN  1076507.0  ...     723387
# 2019-10-07       1300   632000.0  1485200.0   616800.0  ...     581100
# 2019-10-04       7600   514800.0  1551100.0   862900.0  ...     478200
# 2019-10-03       6700   539900.0  1615900.0   552700.0  ...     401000
# 2019-10-02      11100   808300.0  1482700.0  1600600.0  ...     575400
#
#             volumeWFT  volumeWJA  volumeWPRT  volumeWTE  volumeWPK  volumeYRI  \
# date
# 2019-10-08     299167     200145       25623   283884.0      53040    2200431
# 2019-10-07     300700     158900       57000   317600.0      27300    1931600
# 2019-10-04     231100     651100       22800   159600.0      69100    2234300
# 2019-10-03     291800     430000      108600   281900.0      49300    3575800
# 2019-10-02     294600     284400      139800   268500.0     150400    2988600
#
#             volumeY  volumeYRB  volumeZAR
# date
# 2019-10-08   6422.0     100000      17832
# 2019-10-07   1400.0     125000      46700
# 2019-10-04   4300.0          0        100
# 2019-10-03   1600.0     233000       4100
# 2019-10-02   6300.0     979400      12800
#
# [5 rows x 207 columns]

# %%
df_price.to_csv('price.csv')

# %%
df_volume.to_csv('volume.csv')

# %%
df = get_stock("TSE:FAP")

# %%
df.tail()
# Out:
#              price  volume
# date
# 2000-01-10  1.3421   53800
# 2000-01-07  1.3755   42200
# 2000-01-06  1.3254   42500
# 2000-01-05  1.3171   38700
# 2000-01-04  1.3338   51300

# %%
import matplotlib.pyplot as plt

# %%
df.price.plot()

# %% [markdown]
# ## 3. Get the important indices

# %%
from pandas_datareader.bankofcanada import BankOfCanadaReader
from pandas_datareader import DataReader

# %%
start = date(2005,1,1)
end = date(2019,9,30)
df = DataReader('AAPL', 'iex', start, end, api_key="pk_548fc57cbb4e4954b30376d9dedea5a5")

# %%
df.head()
# Out:
#               open    high     low   close     volume
# date
# 2014-10-10  100.69  102.03  100.30  100.73   66331592
# 2014-10-13  101.33  101.78   99.81   99.81   53583368
# 2014-10-14  100.39  100.52   98.57   98.75   63688562
# 2014-10-15   97.97   99.15   95.18   97.54  100933600
# 2014-10-16   95.55   97.72   95.41   96.26   72154523

# %%
df.close.plot()

# %%
start = date(2004,1,1)
end = date(2019,9,30)
df = BankOfCanadaReader('lists', start = start, end = end)

# %%
df.read()
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-212-a33fc9e75cdd> in <module>()
# ----> 1 df.read()
#
# /home/paul/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py in read(self)
#      98         """Read data from connector"""
#      99         try:
# --> 100             return self._read_one_data(self.url, self.params)
#     101         finally:
#     102             self.close()
#
# /home/paul/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py in _read_one_data(self, url, params)
#     105         """ read one data from specified URL """
#     106         if self._format == "string":
# --> 107             out = self._read_url_as_StringIO(url, params=params)
#     108         elif self._format == "json":
#     109             out = self._get_response(url, params=params).json()
#
# /home/paul/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py in _read_url_as_StringIO(self, url, params)
#     116         Open url (and retry)
#     117         """
# --> 118         response = self._get_response(url, params=params)
#     119         text = self._sanitize_response(response)
#     120         out = StringIO()
#
# /home/paul/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py in _get_response(self, url, params, headers)
#     177             msg += "\nResponse Text:\n{0}".format(last_response_text)
#     178
# --> 179         raise RemoteDataError(msg)
#     180
#     181     def _get_crumb(self, *args):
#
# RemoteDataError: Unable to read URL: http://www.bankofcanada.ca/valet/observations/lists/csv?start_date=2004-01-01&end_date=2019-09-30
# Response Text:
# b'\xef\xbb\xbfSeries lists not found.\nhttps://www.bankofcanada.ca/valet/docs'

# %%
df = BankOfCanadaReader('V41690973', start = start, end = end)
df.read()
# Out:
#             V41690973
# \ndate"
# 2019-08-01      136.8
# 2019-07-01      137.0
# 2019-06-01      136.3
# 2019-05-01      136.6
# 2019-04-01      136.0
# 2019-03-01      135.4
# 2019-02-01      134.5
# 2019-01-01      133.6
# 2018-12-01      133.4
# 2018-11-01      133.5
# 2018-10-01      134.1
# 2018-09-01      133.7
# 2018-08-01      134.2
# 2018-07-01      134.3
# 2018-06-01      133.6
# 2018-05-01      133.4
# 2018-04-01      133.3
# 2018-03-01      132.9
# 2018-02-01      132.5
# 2018-01-01      131.7
# 2017-12-01      130.8
# 2017-11-01      131.3
# 2017-10-01      130.9
# 2017-09-01      130.8
# 2017-08-01      130.5
# 2017-07-01      130.4
# 2017-06-01      130.4
# 2017-05-01      130.5
# 2017-04-01      130.4
# 2017-03-01      129.9
# ...               ...
# 2006-06-01      109.5
# 2006-05-01      109.7
# 2006-04-01      109.2
# 2006-03-01      108.6
# 2006-02-01      108.0
# 2006-01-01      108.2
# 2005-12-01      107.6
# 2005-11-01      107.7
# 2005-10-01      107.9
# 2005-09-01      108.4
# 2005-08-01      107.5
# 2005-07-01      107.1
# 2005-06-01      106.9
# 2005-05-01      106.7
# 2005-04-01      106.6
# 2005-03-01      106.3
# 2005-02-01      105.7
# 2005-01-01      105.3
# 2004-12-01      105.4
# 2004-11-01      105.6
# 2004-10-01      105.2
# 2004-09-01      105.0
# 2004-08-01      104.8
# 2004-07-01      105.0
# 2004-06-01      105.1
# 2004-05-01      105.0
# 2004-04-01      104.1
# 2004-03-01      103.9
# 2004-02-01      103.5
# 2004-01-01      103.3
#
# [188 rows x 1 columns]

# %%
df = DataReader('DEXCAUS','fred', start = start, end = end)

# %%
df
# Out:
#             DEXCAUS
# DATE
# 2004-01-01      NaN
# 2004-01-02   1.2900
# 2004-01-05   1.2803
# 2004-01-06   1.2824
# 2004-01-07   1.2884
# 2004-01-08   1.2790
# 2004-01-09   1.2690
# 2004-01-12   1.2735
# 2004-01-13   1.2729
# 2004-01-14   1.2866
# 2004-01-15   1.2990
# 2004-01-16   1.2975
# 2004-01-19      NaN
# 2004-01-20   1.2861
# 2004-01-21   1.3018
# 2004-01-22   1.2970
# 2004-01-23   1.3115
# 2004-01-26   1.3130
# 2004-01-27   1.3048
# 2004-01-28   1.3218
# 2004-01-29   1.3340
# 2004-01-30   1.3265
# 2004-02-02   1.3385
# 2004-02-03   1.3374
# 2004-02-04   1.3330
# 2004-02-05   1.3318
# 2004-02-06   1.3297
# 2004-02-09   1.3304
# 2004-02-10   1.3289
# 2004-02-11   1.3178
# ...             ...
# 2019-08-20   1.3331
# 2019-08-21   1.3275
# 2019-08-22   1.3295
# 2019-08-23   1.3319
# 2019-08-26   1.3282
# 2019-08-27   1.3274
# 2019-08-28   1.3299
# 2019-08-29   1.3299
# 2019-08-30   1.3290
# 2019-09-02      NaN
# 2019-09-03   1.3332
# 2019-09-04   1.3248
# 2019-09-05   1.3238
# 2019-09-06   1.3170
# 2019-09-09   1.3140
# 2019-09-10   1.3141
# 2019-09-11   1.3199
# 2019-09-12   1.3209
# 2019-09-13   1.3268
# 2019-09-16   1.3240
# 2019-09-17   1.3249
# 2019-09-18   1.3283
# 2019-09-19   1.3258
# 2019-09-20   1.3268
# 2019-09-23   1.3271
# 2019-09-24   1.3253
# 2019-09-25   1.3279
# 2019-09-26   1.3271
# 2019-09-27   1.3250
# 2019-09-30   1.3243
#
# [4108 rows x 1 columns]
